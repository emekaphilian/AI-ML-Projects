# %% [markdown]
# ![Smart contract project image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# # 🛡️ Smart Contract Risk Correlation Analysis
#
# ## 🔍 Overview
# This project focuses on uncovering hidden relationships and risks within smart contracts by analyzing binary metadata using Phi coefficients. The objective is to identify significant correlations among contract features to enhance transparency, security, and informed decision-making in decentralized finance (DeFi).
#
# ## 🎯 Objectives
# - Identify statistically significant correlations among smart contract risk indicators.
# - Highlight potential security red flags through metadata analysis.
# - Provide actionable insights for developers, auditors, and stakeholders.
# - Support transparency and decentralization in DeFi systems.
#
# ## 🧪 Methods
# - **Data Preprocessing**: Cleaned and categorized binary smart contract features.
# - **Statistical Analysis**: Applied the Phi coefficient (ϕ) to measure associations between binary variables.
# - **Visualization**: Built a correlation heatmap for intuitive interpretation.
# - **Interpretation**: Analyzed top correlations for actionable risk insights.
#
#
#
# ## 🧰 Tools Used
# - **Python**: Pandas, Seaborn, Matplotlib
# - **Statistical Analysis**: Phi Coefficient (ϕ)
# - **Visualization**: Correlation heatmaps, pairwise comparisons
#
# ## ✅ Professional Skills Applied
# - Data Entry & Annotation
# - Data Analysis & Statistical Reasoning
# - Python Scripting
# - Data Visualization
# - Blockchain Risk Interpretation
# - Smart Contract Vulnerability Analysis
#
# ## 📌 Conclusion
# This analysis surfaces important associations that may help detect fraud, improve smart contract architecture, and guide auditing practices. Understanding the interplay between closed-source code, ownership opacity, honeypots, and reentrancy bugs supports a more secure and transparent DeFi environment.
#
# By leveraging insights from binary correlations, developers and auditors can better prioritize threat mitigation and support decentralized governance in blockchain systems.
#
# ---
#
# ## 📎 Download
# You can download or fork the project files and visualizations from [GitHub Repository](#) (link placeholder).
#
# ---

# %% [markdown]
# **Getting Google Colab Prepared**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Uploading Dataset To Google Drive**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f3090a74-2bb8-4067-9d82-e7f8a5993906" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3090a74-2bb8-4067-9d82-e7f8a5993906">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Import Library**

# %%
# importing the necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Display plots inline
# %matplotlib inline

# %% [markdown]
# **Loading The Dataset**

# %%
# Uploading the dataset

data_set = pd.read_excel("risk_data.xlsx")

# Display the first 10 rows

data_set.head(10)
# Out:
#      project_name                      Smart contract address  \
# 0  Data Analytics    384571416209d08623c6ace9422613fc8970475d
# 1  Data Analytics   0xAb5801a7D398351b8bE11C439e05C5B3259ae9B
# 2  Data Analytics  0x4B20993Bc481177ec7E8f571ceCaE8A9e22C02db
# 3  Data Analytics  0x78731D3Ca6b7E34aC0F824c42a7cC18A495cabaB
# 4  Data Analytics  0x617F2E2fD72FD9D5503197092aC168c91465E7f2
# 5  Data Analytics  0x3f5CE5FBFe3E9af3971dD833D26bA9b5C936f0bE
# 6  Data Analytics  0x1aE0EA34a72D944a8C7603FfB3eC30a6669E454C
# 7  Data Analytics  0x4E984938A8d2C2c923D0dA80A950c8b661F29E02
# 8  Data Analytics  0x90e63c3d53E0Ea496845b7a03ec7548B70014A91
# 9  Data Analytics  0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee
#
#                                       Blog post link  \
# 0  https://chainsecurity.com/security-audit/circl...
# 1  https://stackoverflow.com/questions/75030483/w...
# 2  https://stackoverflow.com/questions/71115106/s...
# 3  https://stackoverflow.com/questions/75030483/w...
# ...

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# Performing EDA

data_set.info()
data_set.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 38 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   project_name                                1093 non-null   object
#  1   Smart contract address                      1093 non-null   object
#  2   Blog post link                              1093 non-null   object
#  3   Audit website                               1093 non-null   object
#  4   Chain                                       1093 non-null   object
#  5   Is_closed_source                            1093 non-null   bool
#  6   hidden_owner                                1093 non-null   bool
#  7   anti_whale_modifiable                       1093 non-null   bool
#  8   Is_anti_whale                               1093 non-null   bool
#  9   Is_honeypot                                 1093 non-null   bool
# ...

# %%
# Data Cleaning
# Handle missing values
data_set = data_set.dropna()  # or data_set.fillna(value)

# Check for duplicates
data_set = data_set.drop_duplicates()

# %% [markdown]
# **Frequency Analysis**

# %%
# Let's now look at the value counts of an individual risk tag: for example incorrect_inheritance_order

data_set['incorrect_inheritance_order'].value_counts()
# Out:
# incorrect_inheritance_order
# False    633
# True      68
# Name: count, dtype: int64

# %%
risk_columns = ['Is_closed_source', 'hidden_owner', 'anti_whale_modifiable',
       'Is_anti_whale', 'Is_honeypot', 'buy_tax', 'sell_tax',
       'slippage_modifiable', 'Is_blacklisted', 'can_take_back_ownership',
       'owner_change_balance', 'is_airdrop_scam', 'selfdestruct', 'trust_list',
       'is_whitelisted', 'is_fake_token', 'illegal_unicode', 'exploitation',
       'bad_contract', 'reusing_state_variable', 'encode_packed_collision',
       'encode_packed_parameters', 'centralized_risk_medium',
       'centralized_risk_high', 'centralized_risk_low', 'event_setter',
       'external_dependencies', 'immutable_states',
       'reentrancy_without_eth_transfer', 'incorrect_inheritance_order',
       'shadowing_local', 'events_maths']

# %%
# Calculating the frequency of 'TRUE' in each risk tag column

frequencies = data_set[risk_columns].apply(lambda x: x.value_counts()).loc[True]

# Replace NaN with 0 for any column that may not have True values
frequencies = frequencies.fillna(0)
frequencies
# Out:
# Is_closed_source                    95
# hidden_owner                       118
# anti_whale_modifiable               83
# Is_anti_whale                       92
# Is_honeypot                         64
# buy_tax                             87
# sell_tax                            84
# slippage_modifiable                 97
# Is_blacklisted                      47
# can_take_back_ownership            140
# owner_change_balance               153
# is_airdrop_scam                     46
# selfdestruct                        82
# trust_list                         110
# is_whitelisted                      71
# is_fake_token                       59
# illegal_unicode                     40
# exploitation                       298
# bad_contract                       238
# reusing_state_variable              81
# encode_packed_collision             52
# encode_packed_parameters            58
# centralized_risk_medium            181
# centralized_risk_high              138
# ...

# %%
# Visualizing the frequencies of "TRUE" using a bar chart

sns.set_style("whitegrid")
plt.figure(figsize=(12, 8))
sns.barplot(x=frequencies.index, y=frequencies.values, palette='viridis')
plt.title('Frequency of True Values for Each Risk Tag')
plt.xlabel('Risk Tags')
plt.ylabel('Frequency of True')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-11-d4f3605dd38a>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=frequencies.index, y=frequencies.values, palette='viridis')

# %%
# Calculating the frequency of 'FALSE' in each risk tag column

frequencies = data_set[risk_columns].apply(lambda x: x.value_counts()).loc[False]

# Replace NaN with 0 for any column that may not have True values
frequencies = frequencies.fillna(0)
frequencies
# Out:
# Is_closed_source                   606
# hidden_owner                       583
# anti_whale_modifiable              618
# Is_anti_whale                      609
# Is_honeypot                        637
# buy_tax                            614
# sell_tax                           617
# slippage_modifiable                604
# Is_blacklisted                     654
# can_take_back_ownership            561
# owner_change_balance               548
# is_airdrop_scam                    655
# selfdestruct                       619
# trust_list                         591
# is_whitelisted                     630
# is_fake_token                      642
# illegal_unicode                    661
# exploitation                       403
# bad_contract                       463
# reusing_state_variable             620
# encode_packed_collision            649
# encode_packed_parameters           643
# centralized_risk_medium            520
# centralized_risk_high              563
# ...

# %%
# Visualizing the frequencies of "FALSE" using a bar chart

sns.set_style("whitegrid")
plt.figure(figsize=(12, 8))
sns.barplot(x=frequencies.index, y=frequencies.values, palette='viridis')
plt.title('Frequency of True Values for Each Risk Tag')
plt.xlabel('Risk Tags')
plt.ylabel('Frequency of False')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-13-4a6d3a70768d>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=frequencies.index, y=frequencies.values, palette='viridis')

# %% [markdown]
# **Correlation Analysis**
#
# Phi Coefficient between 'is_airdrop_scam' and 'hidden_owner'

# %%
# To calculate the Phi coefficient, which is suitable for pairs of binary variables,
# we first need to establish a function that can handle this calculation:
# !pip install scipy
import scipy.stats # Import the scipy.stats module

def phi_coefficient(x, y):
    """Calculate the Phi coefficient for two binary variables."""
    # Create a contingency table
    contingency_table = pd.crosstab(x, y)
    # Calculate the phi coefficient from the contingency table
    chi2 = scipy.stats.chi2_contingency(contingency_table, correction=False)[0]
    n = np.sum(np.sum(contingency_table))
    phi = np.sqrt(chi2 / n)
    return phi

# Example calculation between two risk tags
phi = phi_coefficient(data_set['is_airdrop_scam'], data_set['hidden_owner'])
print(f"Phi Coefficient between 'is_airdrop_scam' and 'hidden_owner': {phi}")
# Out:
# ...
# Phi Coefficient between 'is_airdrop_scam' and 'hidden_owner': 0.32729590215771587

# %% [markdown]
# **Phi Coefficient between 'centralized_risk_high' and 'centralized_risk_medium'**

# %%
# To calculate the Phi coefficient, which is suitable for pairs of binary variables,
# we first need to establish a function that can handle this calculation:

def phi_coefficient(x, y):
    """Calculate the Phi coefficient for two binary variables."""
    # Create a contingency table
    contingency_table = pd.crosstab(x, y)
    # Calculate the phi coefficient from the contingency table
    chi2 = scipy.stats.chi2_contingency(contingency_table, correction=False)[0]
    n = np.sum(np.sum(contingency_table))
    phi = np.sqrt(chi2 / n)
    return phi

# Example calculation between two risk tags
phi = phi_coefficient(data_set['centralized_risk_high'], data_set['centralized_risk_medium'])
print(f"Phi Coefficient between 'centralized_risk_high' and 'centralized_risk_medium': {phi}")
# Out:
# Phi Coefficient between 'centralized_risk_high' and 'centralized_risk_medium': 0.23254806769960368

# %% [markdown]
# **Phi coefficient for all the columns**

# %%
risk_columns = ['Is_closed_source', 'hidden_owner', 'anti_whale_modifiable',
       'Is_anti_whale', 'Is_honeypot', 'buy_tax', 'sell_tax',
       'slippage_modifiable', 'Is_blacklisted', 'can_take_back_ownership',
       'owner_change_balance', 'is_airdrop_scam', 'selfdestruct', 'trust_list',
       'is_whitelisted', 'is_fake_token', 'illegal_unicode', 'exploitation',
       'bad_contract', 'reusing_state_variable', 'encode_packed_collision',
       'encode_packed_parameters', 'centralized_risk_medium',
       'centralized_risk_high', 'centralized_risk_low', 'event_setter',
       'external_dependencies', 'immutable_states',
       'reentrancy_without_eth_transfer', 'incorrect_inheritance_order',
       'shadowing_local', 'events_maths']

# %%
risk_data = data_set[risk_columns]

# Create a DataFrame to store Phi coefficients
phi_matrix = pd.DataFrame(index=risk_data.columns, columns=risk_data.columns)

# Calculate Phi coefficient for each pair of binary variables
for var1 in risk_data.columns:
    for var2 in risk_data.columns:
        phi_matrix.loc[var1, var2] = phi_coefficient(risk_data[var1], risk_data[var2])

print("Phi coefficients calculated for all pairs of variables:")
phi_matrix
# Out:
# Phi coefficients calculated for all pairs of variables:
#                                 Is_closed_source hidden_owner  \
# Is_closed_source                             1.0     0.323125
# hidden_owner                            0.323125          1.0
# anti_whale_modifiable                   0.280596      0.36616
# Is_anti_whale                           0.302797     0.389699
# Is_honeypot                             0.395409     0.294212
# buy_tax                                 0.280749     0.455094
# sell_tax                                0.354407     0.444471
# slippage_modifiable                     0.360351     0.393881
# Is_blacklisted                          0.377118     0.275744
# can_take_back_ownership                 0.187932       0.2807
# owner_change_balance                    0.244833     0.251478
# is_airdrop_scam                         0.400016     0.327296
# selfdestruct                            0.296799     0.215867
# ...

# %% [markdown]
# The table displayed shows the **Phi coefficients** (or **phi correlation**), which measure the degree of association between pairs of binary variables. Phi is a measure of association between two variables that take values of 0 or 1 (i.e., binary data). It’s similar to the Pearson correlation coefficient but specifically used for binary data.
#
# Let's break down how to interpret these values:
#
# ### General Interpretation of Phi Coefficients:
# - A **phi coefficient of 1.0** indicates a **perfect positive correlation** between the two variables (i.e., both variables are always 1 or both are always 0).
# - A **phi coefficient of -1.0** indicates a **perfect negative correlation** (i.e., when one variable is 1, the other is always 0, and vice versa).
# - A **phi coefficient of 0.0** indicates **no association** between the variables (i.e., changes in one variable do not predict changes in the other).
#
# ### Example Rows/Columns:
# Here’s a more detailed interpretation of a few rows from the output:
#
# #### 1. **Is_closed_source vs hidden_owner (0.323125)**:
#    - The Phi coefficient of **0.323125** between **Is_closed_source** and **hidden_owner** indicates a **moderate positive association** between these two variables.
#    - This suggests that when one variable is true (1), the other is more likely to be true as well, but the association is not perfect.
#
# #### 2. **Is_closed_source vs anti_whale_modifiable (0.280596)**:
#    - The Phi coefficient of **0.280596** is a **positive but weak correlation**.
#    - This indicates that the presence of one characteristic (e.g., whether a source is closed) slightly increases the likelihood that the system has an anti-whale modification, but it’s a weak relationship.
#
# #### 3. **anti_whale_modifiable vs Is_anti_whale (0.524448)**:
#    - The Phi coefficient of **0.524448** suggests a **moderate to strong positive correlation** between whether an anti-whale mechanism is modifiable and whether the system has an anti-whale feature.
#    - It suggests that these two variables tend to occur together more frequently.
#
# #### 4. **Is_honeypot vs buy_tax (0.376396)**:
#    - The Phi coefficient of **0.376396** suggests a **moderate positive association** between being a honeypot and having a buy tax.
#    - This means that systems with a honeypot feature tend to also have buy taxes, but it's not a perfect relationship.
#
# #### 5. **Is_blacklisted vs centralized_risk_low (0.457328)**:
#    - The Phi coefficient of **0.457328** indicates a **moderate to strong positive correlation** between being blacklisted and having a low centralized risk.
#    - There seems to be a tendency for blacklisted systems to have lower centralized risk, though not perfectly correlated.
#
# #### 6. **reentrancy_without_eth_transfer vs encode_packed_collision (0.508266)**:
#    - A **strong positive correlation** of **0.508266** between `reentrancy_without_eth_transfer` and `encode_packed_collision` suggests that systems with reentrancy vulnerabilities without an ETH transfer tend to also have packed collisions in their encoding. This is a significant relationship.
#
# #### 7. **centralized_risk_medium vs centralized_risk_high (0.232548)**:
#    - The Phi coefficient of **0.232548** is a **weak positive correlation** between medium and high centralized risks.
#    - While there's a slight positive correlation, the relationship is not strong, indicating that the occurrence of one does not strongly predict the occurrence of the other.
#
# ### Key Points for Interpretation:
# - **Strong positive correlations** (values closer to 1) indicate that the two variables are frequently both true or both false at the same time.
# - **Negative correlations** (values closer to -1) show that when one variable is true, the other is likely false.
# - **Weak correlations** (values closer to 0) show that there's little or no relationship between the two variables.
#
# ### Conclusion:
# The matrix provides a detailed look at the associations between various binary features in this dataset.

# %% [markdown]
# **Visualization of  Matrix as a Heatmap**

# %%
# Setting the size of the plot
plt.figure(figsize=(12, 10))

# Creating a heatmap
sns.heatmap(phi_matrix.astype(float), annot=False, fmt=".2f", cmap='binary', vmin=-1, vmax=1)
plt.title('Heatmap of Phi Coefficients Between Risk Tags')
plt.show()

# %%
# From the heatmap, there is a high Phi Coefficient value (0.633826) between "buy_tax" and "sell_tax".
# This indicates an extremely strong positive correlation between these two risk tags in the smart contract data set you analyzed.
phi = phi_coefficient(data_set['buy_tax'], data_set['sell_tax'])
print(f"Phi Coefficient between 'buy_tax' and 'sell_tax': {phi}")
# Out:
# Phi Coefficient between 'buy_tax' and 'sell_tax': 0.6338256366471323

# %% [markdown]
# ### 📊 **Correlation Analysis of Smart Contract Risks**
#
# **Project Summary**
# In this project, I conducted an **advanced frequency and correlation analysis** on a dataset of smart contract risks using Python in Google Colab. The primary objective was to uncover patterns, common vulnerabilities, and potential relationships between various risk tags, which can support smarter and more secure contract interactions on the blockchain. By using tools like **Pandas**, **Matplotlib**, and **Seaborn**, I was able to perform **data loading, cleaning, transformation, and dynamic visualization**, providing an in-depth exploration of risk tag frequencies and correlations within the smart contract ecosystem.
#
# ### 🔍 **Key Insights & Findings**
#
# 1. **Is_closed_source vs hidden_owner (0.323125)**
#    The Phi coefficient of 0.323125 indicates a **moderate positive correlation** between the variables Is_closed_source and hidden_owner. This means that contracts with closed-source code are more likely to have hidden ownership. While not a perfect correlation, this relationship points to a potential risk associated with anonymous or opaque ownership structures in closed-source contracts. A constructive insight from this could be the need for **enhanced transparency** in ownership details, especially for closed-source contracts, to reduce trust issues and mitigate security risks.
#
# 2. **Is_closed_source vs anti_whale_modifiable (0.280596)**
#    The Phi coefficient of 0.280596 represents a **weak positive correlation** between a closed-source contract and the modifiable anti-whale feature. Although the correlation is weak, it suggests that systems with closed-source code might have a slightly higher likelihood of including anti-whale protections. This could be interpreted as a move toward limiting market manipulation, though it remains a loose connection. A possible recommendation is for developers to carefully consider the trade-offs between **market manipulation protections** and the **openness of contract code**.
#
# 3. **anti_whale_modifiable vs Is_anti_whale (0.524448)**
#    The Phi coefficient of 0.524448 suggests a **moderate to strong positive correlation** between having a modifiable anti-whale feature and actually implementing anti-whale mechanisms. This implies that the presence of one often correlates with the presence of the other. This relationship can be seen as positive, as it shows that systems with modifiable anti-whale features are more likely to employ such mechanisms. This highlights the need for **flexible, adjustable anti-whale features** to prevent market manipulation in a decentralized manner while maintaining contract security.
#
# 4. **Is_honeypot vs buy_tax (0.376396)**
#    The Phi coefficient of 0.376396 indicates a **moderate positive association** between contracts labeled as honeypots and those with a buy tax. While this suggests a slight correlation, it doesn't guarantee that every honeypot will have a buy tax. However, it points to a potential **red flag for fraud**. Contracts that combine honeypot characteristics with financial penalties (like buy taxes) should be approached with **caution**, and further scrutiny of transaction fees and contract logic may help identify fraudulent behavior.
#
# 5. **Is_blacklisted vs centralized_risk_low (0.457328)**
#    The Phi coefficient of 0.457328 suggests a **moderate to strong positive correlation** between being blacklisted and having low centralized risk. This correlation could indicate that blacklisted contracts may possess lower levels of centralization, potentially due to regulatory scrutiny or efforts to reduce central control. However, this relationship may be complex and multifaceted, warranting further investigation into **why contracts with lower centralized risk are being blacklisted**. It's important for stakeholders to **monitor centralization** closely to ensure that decentralization is maintained in both compliant and non-compliant projects.
#
# 6. **reentrancy_without_eth_transfer vs encode_packed_collision (0.508266)**
#    The Phi coefficient of 0.508266 suggests a **strong positive correlation** between reentrancy vulnerabilities without ETH transfer and packed collisions in encoding. This indicates that contracts with reentrancy vulnerabilities, which do not involve ETH transfers, are more likely to exhibit encoding issues such as packed collisions. These vulnerabilities could be exploited for **security exploits**, so developers should **prioritize securing reentrancy flaws** and improving encoding practices to prevent such exploits from compromising smart contract integrity.
#
# 7. **centralized_risk_medium vs centralized_risk_high (0.232548)**
#    The Phi coefficient of 0.232548 represents a **weak positive correlation** between medium and high centralized risks. While there is a slight positive correlation, it is not strong enough to suggest that one directly predicts the other. This weak relationship highlights the **complexity of centralization in smart contracts**, suggesting that developers and auditors should evaluate centralization risks on a case-by-case basis rather than relying on broad assumptions.
#
# ### ✅ **Professional Skills Applied**
# - **Data Entry & Annotation**: Labeled and categorized risk tags to support accurate analysis and interpretation of smart contract vulnerabilities.
# - **Data Analysis & Interpretation**: Uncovered key trends and relationships within smart contract metadata.
# - **Python Programming**: Utilized Python libraries (Pandas, Matplotlib, Seaborn) for efficient data manipulation and visualization.
# - **Data Visualization**: Built clear, insightful charts and heatmaps to communicate complex patterns effectively.
# - **Statistical Correlation Techniques**: Applied statistical methods to measure and interpret relationships between risk features.
# - **Problem Solving & Critical Thinking**: Identified actionable insights to improve security practices in decentralized finance (DeFi).
# - **Blockchain Security Knowledge**: Demonstrated a solid grasp of smart contract design, vulnerabilities, and exploit vectors.
#
# ### 📌 **Conclusion**
# This analysis provides valuable insights into the common risks and hidden relationships found in smart contracts. By understanding these vulnerabilities and their interconnections, stakeholders developers, auditors, and users—can make informed decisions, reduce attack surfaces, and improve contract integrity. The findings highlight the need for vigilance, transparency, and continued education in the evolving blockchain landscape.
#
# Constructively, addressing the identified correlations can guide developers to design more secure contracts, implement necessary protections, and maintain the decentralized nature of blockchain systems. Furthermore, leveraging these insights could **inform future security audits** and help mitigate risks in the rapidly growing field of decentralized finance (DeFi).
